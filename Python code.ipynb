# %%
import pandas as pd
import os
import os
import statsmodels.api as sm


os.chdir(r"C:\Users\Lorenzo\Documents\Uni\Ultimo semestre\Polli")


df = pd.read_excel("Polli progetto.xlsx", sheet_name="Foglio4")


print(df.head())

from statsmodels.tsa.stattools import adfuller




from statsmodels.tsa.stattools import adfuller


serie = df["CO2"].dropna() 


result = adfuller(serie)


print("ADF Statistic:", result[0])
print("p-value:", result[1])
for key, value in result[4].items():
    print(f"Critical Value ({key}): {value}")


import pandas as pd
from statsmodels.tsa.stattools import adfuller


df2 = pd.read_excel(r"C:\Users\Lorenzo\Documents\Uni\Ultimo semestre\Polli\Polli progetto.xlsx", sheet_name="Foglio5")
serie2 = df2["GDP"].dropna()  

print(serie2.head())  

# Test di Dickey-Fuller
result2 = adfuller(serie2)


print("ADF Statistic gdp:", result2[0])
print("p-value gdp:", result2[1])
for key, value in result2[4].items():
    print(f"Critical Value gdp ({key}): {value}")

# Differenziazione prima serie (CO2)
co2_diff = serie.diff().dropna()
adf_co2_diff = adfuller(co2_diff)

# Differenziazione seconda serie (GDP)
gdp_diff = serie2.diff().dropna()
adf_gdp_diff = adfuller(gdp_diff)
# Stampa i risultati della differenziazione
print("Differenziazione CO2 - ADF Statistic:", adf_co2_diff[0])
print("Differenziazione CO2 - p-value:", adf_co2_diff[1])
for key, value in adf_co2_diff[4].items():
    print(f"Differenziazione CO2 - Critical Value ({key}): {value}")    

print("Differenziazione GDP - ADF Statistic:", adf_gdp_diff[0])
print("Differenziazione GDP - p-value:", adf_gdp_diff[1])       
for key, value in adf_gdp_diff[4].items():
    print(f"Differenziazione GDP - Critical Value ({key}): {value}")
    
    
   
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt


# ARMA(p=1, q=1) → ARIMA(p=1, d=0, q=1)
model_co2 = ARIMA(co2_diff, order=(1, 0, 1))
result_co2 = model_co2.fit()

print(result_co2.summary())
model_gdp = ARIMA(gdp_diff, order=(1, 0, 1))
result_gdp = model_gdp.fit()

print(result_gdp.summary())
from statsmodels.stats.diagnostic import acorr_ljungbox

# Test Ljung-Box per residui
ljung_co2 = acorr_ljungbox(result_co2.resid, lags=[10], return_df=True)
print(ljung_co2)


import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA



model_co2_arma21 = ARIMA(co2_diff, order=(2, 0, 1))
result_co2_arma21 = model_co2_arma21.fit()
print("\n=== ARMA(2,1) per CO2 ===")
print(result_co2_arma21.summary())


model_co2_arma12 = ARIMA(co2_diff, order=(1, 0, 2))
result_co2_arma12 = model_co2_arma12.fit()
print("\n=== ARMA(1,2) per CO2 ===")
print(result_co2_arma12.summary())


model_gdp_arma21 = ARIMA(gdp_diff, order=(2, 0, 1))
result_gdp_arma21 = model_gdp_arma21.fit()
print("\n=== ARMA(2,1) per GDP ===")
print(result_gdp_arma21.summary())


model_gdp_arma12 = ARIMA(gdp_diff, order=(1, 0, 2))
result_gdp_arma12 = model_gdp_arma12.fit()
print("\n=== ARMA(1,2) per GDP ===")
print(result_gdp_arma12.summary())







import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.graphics.tsaplots import plot_acf


co2_diff = pd.Series(co2_diff)

# Test di Ljung-Box per il rumore bianco
lb_test = acorr_ljungbox(co2_diff, lags=[10], return_df=True)

print("📊 Test di Ljung-Box su co2_diff:")
print(lb_test)


plot_acf(co2_diff, lags=20)
plt.title("Autocorrelazione (ACF) di co2_diff")
plt.xlabel("Lag")
plt.ylabel("Autocorrelazione")
plt.grid(True)
plt.show()




co2_diff = pd.Series(gdp_diff)


lb_test_gdp = acorr_ljungbox(gdp_diff, lags=[10], return_df=True)

print("📊 Test di Ljung-Box su co2_diff:")
print(lb_test_gdp)



plot_acf(gdp_diff, lags=20)
plt.title("Autocorrelazione (ACF) di gdp_diff")
plt.xlabel("Lag")
plt.ylabel("Autocorrelazione")
plt.grid(True)
plt.show()

from statsmodels.tsa.arima.model import ARIMA

# Modello costante sulla serie differenziata
model_const = ARIMA(co2_diff, order=(0, 0, 0))
result_const = model_const.fit()

print("📘 ARIMA(0,0,0) - Modello costante:")
print(result_const.summary())

# Modello random walk sulla serie originale (non differenziata!)
model_rw = ARIMA(serie, order=(0, 1, 0)) 
result_rw = model_rw.fit()

print("📗 ARIMA(0,1,0) - Random Walk:")
print(result_rw.summary())


from statsmodels.tsa.arima.model import ARIMA

# === 1. Modello costante: ARIMA(0,0,0) sulla serie differenziata
model_const_gdp = ARIMA(gdp_diff, order=(0, 0, 0))
result_const_gdp = model_const_gdp.fit()

print("📘 ARIMA(0,0,0) - Modello costante per GDP differenziato:")
print(result_const_gdp.summary())


# === 2. Modello random walk: ARIMA(0,1,0) sulla serie originale
model_rw_gdp = ARIMA(serie2, order=(0, 1, 0)) 
result_rw_gdp = model_rw_gdp.fit()

print("\n📗 ARIMA(0,1,0) - Random Walk per GDP originale:")
print(result_rw_gdp.summary())

from statsmodels.tsa.arima.model import ARIMA

# Modello costante sulla serie differenziata
model_const = ARIMA(co2_diff, order=(0, 0, 0))
result_const = model_const.fit()

print("📘 ARIMA(0,0,0) - Modello costante:")
print(result_const.summary())
# Out:
#    Time         CO2
# 0  1997  401.287301
# 1  1998  411.832176
# 2  1999  417.730612
# 3  2000  420.436632
# 4  2001  420.181390
# ADF Statistic: -0.05420946879336472
# p-value: 0.9538127262276226
# Critical Value (1%): -3.7238633119999998
# Critical Value (5%): -2.98648896
# Critical Value (10%): -2.6328004
# 0    1632164.60
# 1    1661716.85
# 2    1688731.85
# 3    1752683.35
# 4    1786884.70
# Name: GDP, dtype: float64
# ADF Statistic gdp: -2.8140115390512372
# p-value gdp: 0.05630002530006701
# Critical Value gdp (1%): -3.7238633119999998
# Critical Value gdp (5%): -2.98648896
# Critical Value gdp (10%): -2.6328004
# Differenziazione CO2 - ADF Statistic: -4.8788408971802415
# Differenziazione CO2 - p-value: 3.8336995471363774e-05
# Differenziazione CO2 - Critical Value (1%): -3.7377092158564813
# Differenziazione CO2 - Critical Value (5%): -2.9922162731481485
# Differenziazione CO2 - Critical Value (10%): -2.635746736111111
# Differenziazione GDP - ADF Statistic: -3.971099264365803
# Differenziazione GDP - p-value: 0.001569638611929971
# Differenziazione GDP - Critical Value (1%): -3.7529275211638033
# Differenziazione GDP - Critical Value (5%): -2.998499866852963
# Differenziazione GDP - Critical Value (10%): -2.6389669754253307
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    CO2   No. Observations:                   25
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -105.859
# Date:                Tue, 15 Jul 2025   AIC                            219.718
# Time:                        12:57:14   BIC                            224.593
# Sample:                             0   HQIC                           221.070
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.9772      5.166     -0.770      0.441     -14.102       6.148
# ar.L1          0.7258      1.888      0.384      0.701      -2.975       4.426
# ma.L1         -0.6792      1.987     -0.342      0.732      -4.573       3.215
# sigma2       278.8003     80.082      3.481      0.000     121.842     435.759
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):                 0.78
# Prob(Q):                              0.65   Prob(JB):                         0.68
# Heteroskedasticity (H):               2.92   Skew:                            -0.18
# Prob(H) (two-sided):                  0.15   Kurtosis:                         3.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    GDP   No. Observations:                   25
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -307.921
# Date:                Tue, 15 Jul 2025   AIC                            623.842
# Time:                        12:57:14   BIC                            628.718
# Sample:                             0   HQIC                           625.194
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9553.8466   8655.108      1.104      0.270   -7409.853    2.65e+04
# ar.L1          0.4050      1.017      0.398      0.690      -1.588       2.398
# ma.L1         -0.5915      1.000     -0.592      0.554      -2.551       1.368
# sigma2      3.191e+09      0.087   3.67e+10      0.000    3.19e+09    3.19e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                12.89
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.08   Skew:                            -1.28
# Prob(H) (two-sided):                  0.01   Kurtosis:                         5.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.32e+25. Standard errors may be unstable.
#      lb_stat  lb_pvalue
# 10  5.027423   0.889339
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# === ARMA(2,1) per CO2 ===
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    CO2   No. Observations:                   25
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                -105.635
# Date:                Tue, 15 Jul 2025   AIC                            221.270
# Time:                        12:57:15   BIC                            227.365
# Sample:                             0   HQIC                           222.961
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.5984      6.175     -0.583      0.560     -15.700       8.503
# ar.L1          0.5100      1.494      0.341      0.733      -2.418       3.438
# ar.L2          0.1432      0.525      0.273      0.785      -0.886       1.173
# ma.L1         -0.5469      1.414     -0.387      0.699      -3.319       2.225
# sigma2       273.3168     83.598      3.269      0.001     109.467     437.166
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.08
# Prob(Q):                              0.95   Prob(JB):                         0.58
# Heteroskedasticity (H):               2.97   Skew:                            -0.34
# Prob(H) (two-sided):                  0.15   Kurtosis:                         3.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# === ARMA(1,2) per CO2 ===
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    CO2   No. Observations:                   25
# Model:                 ARIMA(1, 0, 2)   Log Likelihood                -105.584
# Date:                Tue, 15 Jul 2025   AIC                            221.169
# Time:                        12:57:16   BIC                            227.263
# Sample:                             0   HQIC                           222.859
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.5255      6.558     -0.538      0.591     -16.379       9.328
# ar.L1          0.7006      0.729      0.961      0.337      -0.729       2.130
# ma.L1         -0.7597      0.723     -1.051      0.293      -2.177       0.658
# ma.L2          0.1665      0.432      0.385      0.700      -0.681       1.014
# sigma2       271.9039     87.224      3.117      0.002     100.947     442.861
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.21
# Prob(Q):                              0.98   Prob(JB):                         0.55
# Heteroskedasticity (H):               3.00   Skew:                            -0.39
# Prob(H) (two-sided):                  0.14   Kurtosis:                         3.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# === ARMA(2,1) per GDP ===
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    GDP   No. Observations:                   25
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                -307.371
# Date:                Tue, 15 Jul 2025   AIC                            624.741
# Time:                        12:57:16   BIC                            630.836
# Sample:                             0   HQIC                           626.432
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9553.8467   8937.583      1.069      0.285   -7963.494    2.71e+04
# ar.L1         -0.2237      1.427     -0.157      0.875      -3.021       2.574
# ar.L2         -0.3044      0.465     -0.654      0.513      -1.216       0.608
# ma.L1          0.0596      1.425      0.042      0.967      -2.733       2.853
# sigma2      2.974e+09      0.088   3.37e+10      0.000    2.97e+09    2.97e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                14.84
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.26   Skew:                            -1.31
# Prob(H) (two-sided):                  0.02   Kurtosis:                         5.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.39e+26. Standard errors may be unstable.
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# === ARMA(1,2) per GDP ===
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    GDP   No. Observations:                   25
# Model:                 ARIMA(1, 0, 2)   Log Likelihood                -307.919
# Date:                Tue, 15 Jul 2025   AIC                            625.838
# Time:                        12:57:16   BIC                            631.933
# Sample:                             0   HQIC                           627.528
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9553.8467   1.08e+04      0.888      0.375   -1.15e+04    3.06e+04
# ar.L1         -0.3210      2.208     -0.145      0.884      -4.649       4.007
# ma.L1          0.1739      2.198      0.079      0.937      -4.135       4.483
# ma.L2         -0.2658      0.554     -0.480      0.631      -1.351       0.820
# sigma2      3.694e+09      0.089   4.16e+10      0.000    3.69e+09    3.69e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                14.03
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.67   Skew:                            -1.27
# Prob(H) (two-sided):                  0.01   Kurtosis:                         5.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.47e+27. Standard errors may be unstable.
# 📊 Test di Ljung-Box su co2_diff:
#      lb_stat  lb_pvalue
# 10  5.785072   0.832986
# 📊 Test di Ljung-Box su co2_diff:
#      lb_stat  lb_pvalue
# 10  4.809902    0.90351
# 📘 ARIMA(0,0,0) - Modello costante:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    GDP   No. Observations:                   25
# Model:                          ARIMA   Log Likelihood                -336.570
# Date:                Tue, 15 Jul 2025   AIC                            677.140
# Time:                        12:57:16   BIC                            679.578
# Sample:                             0   HQIC                           677.817
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9553.8468   2.75e+05      0.035      0.972    -5.3e+05    5.49e+05
# sigma2      7.553e+10   3.14e+10      2.408      0.016    1.41e+10    1.37e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):                13.51
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.03   Skew:                            -1.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 📗 ARIMA(0,1,0) - Random Walk:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    CO2   No. Observations:                   26
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                -106.674
# Date:                Tue, 15 Jul 2025   AIC                            215.347
# Time:                        12:57:16   BIC                            216.566
# Sample:                             0   HQIC                           215.685
#                                  - 26
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       297.6967     71.355      4.172      0.000     157.843     437.551
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.72
# Prob(Q):                              0.88   Prob(JB):                         0.70
# Heteroskedasticity (H):               4.61   Skew:                            -0.28
# Prob(H) (two-sided):                  0.04   Kurtosis:                         3.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 📘 ARIMA(0,0,0) - Modello costante per GDP differenziato:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    GDP   No. Observations:                   25
# Model:                          ARIMA   Log Likelihood                -336.570
# Date:                Tue, 15 Jul 2025   AIC                            677.140
# Time:                        12:57:16   BIC                            679.578
# Sample:                             0   HQIC                           677.817
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9553.8468   2.75e+05      0.035      0.972    -5.3e+05    5.49e+05
# sigma2      7.553e+10   3.14e+10      2.408      0.016    1.41e+10    1.37e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):                13.51
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.03   Skew:                            -1.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# 📗 ARIMA(0,1,0) - Random Walk per GDP originale:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    GDP   No. Observations:                   26
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                -308.716
# Date:                Tue, 15 Jul 2025   AIC                            619.432
# Time:                        12:57:16   BIC                            620.651
# Sample:                             0   HQIC                           619.770
#                                  - 26
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      2.993e+09   5.67e+08      5.277      0.000    1.88e+09     4.1e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):                13.51
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.82   Skew:                            -1.02
# Prob(H) (two-sided):                  0.01   Kurtosis:                         5.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 📘 ARIMA(0,0,0) - Modello costante:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    GDP   No. Observations:                   25
# Model:                          ARIMA   Log Likelihood                -336.570
# Date:                Tue, 15 Jul 2025   AIC                            677.140
# Time:                        12:57:16   BIC                            679.578
# Sample:                             0   HQIC                           677.817
#                                  - 25
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9553.8468   2.75e+05      0.035      0.972    -5.3e+05    5.49e+05
# sigma2      7.553e+10   3.14e+10      2.408      0.016    1.41e+10    1.37e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):                13.51
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.03   Skew:                            -1.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\Lorenzo\scoop\apps\python\3.13.0\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
